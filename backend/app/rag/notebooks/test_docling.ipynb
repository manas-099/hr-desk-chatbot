# %%
from pathlib import Path
from docling.document_converter import DocumentConverter

pdf_path = Path("../source_docs/Quilltony_Technologies_Compensation_Guidelines.pdf")
print("Exists?", pdf_path.exists())   # should now print True

converter = DocumentConverter()
result = converter.convert(str(pdf_path))
doc = result.document

markdown_output = doc.export_to_markdown()
print(markdown_output)
# Out:
# Exists? True
# [INFO] 2026-08-01 13:16:38,823 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-08-01 13:16:38,843 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\RentoBees\Desktop\HR_Policy_Desk\hr_env\Lib\site-packages\rapidocr\models\PP-OCRv6_det_small.onnx
# [INFO] 2026-08-01 13:16:38,845 [RapidOCR] main.py:63: Using C:\Users\RentoBees\Desktop\HR_Policy_Desk\hr_env\Lib\site-packages\rapidocr\models\PP-OCRv6_det_small.onnx
# [INFO] 2026-08-01 13:16:38,945 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-08-01 13:16:38,947 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\RentoBees\Desktop\HR_Policy_Desk\hr_env\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_mobile.onnx
# [INFO] 2026-08-01 13:16:38,947 [RapidOCR] main.py:63: Using C:\Users\RentoBees\Desktop\HR_Policy_Desk\hr_env\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_mobile.onnx
# ...

# %%
import os
print(os.path.exists("guardrails/config.yml"))
print(os.listdir("guardrails") if os.path.exists("guardrails") else "guardrails folder missing")
# Out:
# False
# guardrails folder missing

# %%
# Out:
# ['kb', 'rails']
